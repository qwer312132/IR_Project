# %%
# !pip install fasttext
# !pip install huggingface_hub
# Out:
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pybind11>=2.2 (from fasttext)
#   Using cached pybind11-2.12.0-py3-none-any.whl (234 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext) (67.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasttext) (1.25.2)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4227137 sha256=101b3df7d6c01b953c9f5bd1de6b2597959c2fc81e8051762f8850477dc9595e
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.2 pybind11-2.12.0
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.20.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.11.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (24.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2024.2.2)

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
import tensorflow_hub as hub
import fasttext
from huggingface_hub import hf_hub_download
from tensorflow import keras
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold

# %%
print("Version: ", tf.__version__)
print("Eager mode: ", tf.executing_eagerly())
print("Hub version: ", hub.__version__)
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Out:
# Version:  2.15.0
# Eager mode:  True
# Hub version:  0.16.1
# GPU is available

# %%
# 讀取.json
with open('./comments.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# 提取 'comment' 與 'ad'
comments = [entry['comment'] for entry in data]
ads = [entry['ad'] for entry in data]

# %%
model_path = hf_hub_download(repo_id="facebook/fasttext-zh-vectors", filename="model.bin")
embad_model = fasttext.load_model(model_path)
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
# 將資料分成訓練集和測試集（4:1）
X_train, X_test, y_train, y_test = train_test_split(comments, ads, test_size=0.2, random_state=42, stratify=ads)

# %%
X_train_embed = [embad_model[x] for x in X_train]
X_test_embed = [embad_model[x] for x in X_test]

# %%
# 定義交叉驗證的折數
num_folds = 5
# 初始化 StratifiedKFold
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# %%
# 創建空列表來保存每個折數的訓練和驗證分數
train_scores = []
val_scores = []

# %%
for fold, (train_index, val_index) in enumerate(kfold.split(X_train, y_train)):
    print(f"Training on fold {fold + 1}/{num_folds}...")
    # 根據索引拆分訓練和驗證資料(from train data)
    trainX = np.array([X_train_embed[i] for i in train_index])
    valX = np.array([X_train_embed[i] for i in val_index])
    trainY = np.array([y_train[i] for i in train_index])
    valY = np.array([y_train[i] for i in val_index])
    # 計算類別權重
    train_class_weights = compute_class_weight('balanced', classes = np.unique(trainY), y = trainY)

    val_class_weights = compute_class_weight('balanced', classes = np.unique(valY), y = valY)
    val_sample_weights = np.zeros(len(valY))
    val_sample_weights[valY == 1] = val_class_weights[1]
    val_sample_weights[valY == 0] = val_class_weights[0]

    # 將類別權重轉換為字典格式
    train_class_weights = dict(enumerate(train_class_weights))

    model = tf.keras.Sequential([
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(1)
    ])

    # 編譯模型
    model.compile(optimizer='adam',
                  loss=tf.losses.BinaryCrossentropy(from_logits=True),
                  metrics=[keras.metrics.RecallAtPrecision(precision=0.8)])

    # 訓練模型
    history = model.fit(trainX,
                        trainY,
                        epochs=40,
                        batch_size=512,
                        verbose=0,
                        validation_data=(valX, valY, val_sample_weights),
                        class_weight=train_class_weights)

    # 評估模型
    train_score = model.evaluate(trainX, trainY, verbose=0)
    val_score = model.evaluate(valX, valY, verbose=0)

    train_scores.append(train_score)
    val_scores.append(val_score)

# %%
# 輸出每個折數的平均訓練和驗證分數
print("Average training scores:", np.mean(train_scores, axis=0))
print("Average validation scores:", np.mean(val_scores, axis=0))
# Out:
# Average training scores: [0.06774803 1.        ]
# Average validation scores: [0.10432098 0.44225609]

# %%
y_pred = model.predict(np.array(X_test_embed), verbose=1)
y_pred = (y_pred > 0.5).astype(np.integer)
# Out:
# 59/59 [==============================] - 0s 2ms/step
# <ipython-input-106-fa0d75743cf9>:2: DeprecationWarning: Converting `np.integer` or `np.signedinteger` to a dtype is deprecated. The current result is `np.dtype(np.int_)` which is not strictly correct. Note that the result depends on the system. To ensure stable results use may want to use `np.int64` or `np.int32`.
#   y_pred = (y_pred > 0.5).astype(np.integer)

# %%
y_test_np = np.array(y_test)
y_test_np = y_test_np[:, np.newaxis]
# accuracy = (y_pred == y_test_np).mean()
ad00 = np.logical_and(y_test_np == 0, y_pred == 0)
ad01 = np.logical_and(y_test_np == 0, y_pred == 1)
ad10 = np.logical_and(y_test_np == 1, y_pred == 0)
ad11 = np.logical_and(y_test_np == 1, y_pred == 1)
print("測試資料的數量:", len(y_test))
print("召回率:", sum(ad11) / (sum(ad10) + sum(ad11)))
print("本身不是廣告且判斷不是廣告的數量:", sum(ad00))
print("本身不是廣告且判斷是廣告的數量:", sum(ad01))
print("本身是廣告且判斷不是廣告的數量:", sum(ad10))
print("本身是廣告且判斷是廣告的數量:", sum(ad11))
# Out:
# 測試資料的數量: 1867
# 召回率: [0.84313725]
# 本身不是廣告且判斷不是廣告的數量: [1791]
# 本身不是廣告且判斷是廣告的數量: [25]
# 本身是廣告且判斷不是廣告的數量: [8]
# 本身是廣告且判斷是廣告的數量: [43]

# %%
X_test_np = np.array(X_test)
X_test_np = X_test_np[:, np.newaxis]

# %%
ad_pred = X_test_np[y_pred == 1]
print("判斷為廣告的數量:", len(ad_pred))
print("判斷為廣告的句子:\n", ad_pred)
# Out:
# 判斷為廣告的數量: 68
# 判斷為廣告的句子:
#  ['讓我告訴你HBO277點c歐m上可以體驗一下無縣圓寶手遊，登入就享至尊會員，還有原創角色交易系統，玩膩了可以換現金。但自從最近更新了就不能進入遊戲。一開遊戲就閃退，帳號也一直不能成功梆定。希望有人可連絡我提供協助。人物和景色處理都獨樹一格，每-個地方都環環相扣，讓我體驗到遊戲設計師的創意小巧思，非常耐玩，而且劇情引人入勝，但是在敘事的時間也不會冗長，把握的剛剛好，跟我以前玩的手遊完全不一樣，是一個有層次跟故事的遊戲。'
#  '請問一下現在是要維修到什麼時候會不會修太久了也沒有時間到底是要玩家等爽的喔'
#  '我是一個熱愛天堂的小課玩家，本來對遊戲體驗雖然也有諸多小怨言，本著玩遊戲的心態也就得過且過，但是這一次 (亞特蘭提斯) 活動讓我感覺在 繼續課金就是白痴，遊戲體驗之糟糕 瞬間爆錶，為了一個解活動 任務 明知道會被殺，被嘲諷，還要像白痴一樣一直去，浪費一個小時，還是沒解到任務。讓人絕望的是就算我肯 繼續花錢依然無法改變這種糟糕的遊戲體驗。或許止損是我唯一的出路，尋找其他替代遊戲(╥﹏╥)'
#  '超棒的說 活動填滿了小說和動漫的坑 ，我是在knn83.c om找手遊，裡面無需儲值就可以滿級會員和無限錢幣，進去就先送你神裝神獸，每週都還有很多活動禮包更新。還特地再做了動畫 遊戲體驗嗎 感覺出貨很容易的 至少比FGO好了 打的時候也很順手的 就是慢了點 如果週回速度可以再提高的話就更好 活動關卡有掉落物顯示就好 比起SAOMD 好很多 砸了不少錢下去 總括而言 真的挺好的 需要進步的位也有的 佢望能像FGO一樣 一路進步'
#  '天堂m練妖精到50級大概要快一個月，用藍鑽買商品抽也抽不中，（不是商品嗎？為何用抽的）相賭博一樣，花了大概4萬台幣，（不是遊戲而已嗎？）聽說還有人花了80萬來抽，大概是有錢吧？！還跟遊戲公司打官司想把錢要回來，接果呢？這是很好玩的遊戲，別亂經營好嗎？！'
#  '越改越爛 lag到不行 不得已重新下載 我4個帳號都手動 下載後竟然2個帳號沒辦法登入 認證失敗 認證失敗 如果還是這樣不能進入遊戲 我就刪除所以帳號退坑！'
#  '美好的清晨來杯咖啡再配上破解手遊，你會發現生活就是如此簡單，先介紹9MAQ。?óＭ，上線滿V級版可以玩，資源元寶都是無限用的，上線就送無限貨幣，有點晚才發現。不管是場上的判斷還是選角色的判斷多都變化多端，雖然有時會遇到雷對友，但只要和能信任的朋友玩就還好，還有角色很好抽，又可以和麻吉朋友一起玩，這款遊戲讓我今年每天都很快樂。'
#  '爛 電腦版防－60都能吃下大陸大部分地區了 手機版連海音都吃不下 打個任務旁邊全是主動怪 整個畫面10幾隻任務怪才剛要打 主動怪就來了 7～9隻 打死1隻馬上又生2～4隻出來 清完任務怪都跑光了 還常常一直重復這樣 重點任務物品還超難掉 打20～30隻才掉一個 黑妖49級武滿防－60居然比 黑暗騎士47級防－31武加0打同樣怪還弱 大馬爪vs大馬刀 黑妖爆擊加魔法還要6刀 黑騎沒爆擊沒魔法只3～4刀 消耗品還難掉到靠西 基本水晶法書還貴到爆 喝水還只能設紅水 自動練功沒範圍設定 怪也不能只設定想打的 還常常跑去打一些不想打的低等怪 或高等怪 浪費時間'
#  '明明很金典遊戲，被搞的評價那麼爛，外掛無敵什麼都打的到，手動玩家花錢卻什麼都打不到，花了幾萬了，紅變紅娃都沒有，明明卡片旋轉時全紅一張白，停止卻給白的，要賺錢也不能這麼沒天理，不怕那天報應來臨，人在做天在看，要這樣運作，乾脆說明，紅變紅娃一隻買多少給玩家好了'
#  '聽覺上的享受!以後再也不會無聊。還有壹個特別的小技巧告訴大家。在EK433.?om 這裏下載的版本。可以滿V。不用自己充。終於收到我需要的寶貝了。東西很好。價美物廉。說實在這是我來讓我最滿意的一次購物。無論是掌櫃的態度還是對物品。我都非常滿意的。掌櫃態度很專業熱情。有問必答。回復也很快。我問了不少問題。他都不覺得煩。'
#  '玩個遊戲要等1000多號.等到又斷線.到底是給不給人玩啊！如果一直不改善.我看也不用太玩了.比橘子的還要不如。'
#  '聽覺上的享受！以後再也不會無聊。還有壹個特別的小技巧告訴大家。在2021MG。?OM 這裏下載的版本。可以滿V。不用自己充。終於收到我需要的寶貝了。東西很好。價美物廉。說實在這是我來讓我最滿意的一次購物。無論是掌櫃的態度還是對物品。我都非常滿意的。掌櫃態度很專業熱情。有問必答。回復也很快。我問了不少問題。他都不覺得煩。'
#  '視覺上的享受！以後再也不會無聊。還有壹個特別的小技巧告訴大家。在ＴＷＤ122.?OM 這裏下載的版本。可以滿V。不用自己充。終於收到我需要的寶貝了。東西很好。價美物廉。說實在這是我來讓我最滿意的一次購物。無論是掌櫃的態度還是對物品。我都非常滿意的。掌櫃態度很專業熱情。有問必答。回復也很快。我問了不少問題。他都不覺得煩。'
#  '精神上的享受！以後再也不會無聊。還有壹個特別的小技巧告訴大家。在Swa33，希OM 這裏下載的版本。可以滿V。不用自己充。終於收到我需要的寶貝了。東西很好。價美物廉。說實在這是我來讓我最滿意的一次購物。無論是掌櫃的態度還是對物品。我都非常滿意的。掌櫃態度很專業熱情。有問必答。回復也很快。我問了不少問題。他都不覺得煩。'
#  '認真說實話這個遊戲整體上還不錯，但是關卡太小了，我才用了一星期就做完了，而且戰力方面已達到了瓶勁完全升不上，在2004game℃OM 這裏下載的版本。可以滿V。不用自己充。最近開始刷鍛造但這個飛龍骨我用了50張掃蕩卷才中了20個也太坑了吧，期待這個機率能提高，第五章尾二的劇情我完全能看到開發商的努力'
#  '今天吃完鵝蛋了嗎?必须去瀏覽器打開網址2002game·C〇м\u3000上體驗這個遊戲的無限版。遊戲盒裡面幾千款全部都是無限版手遊滿ＶＩＰ無限寶石無限元寶無限貨幣的遊戲。真希望快點更新，玩福利型的滿級V元寶無限版，各種資源啥的都無限。神獸，根本不花錢，遊戲也比較好玩，玩家很多，等什麼呢快來吧我玩了很多網路遊戲，所以這種自動和手動遊戲的結合，襲作團隊調查了優缺點後做出的一種創新各種各樣的手機遊戲。雖然風險很大，但至少他們想換點新東西。所以一開始說實話，我是抱著玩樂的態度來玩的，但沒想到裡面人物設定、技巧和對各種故事的描述都達到了高端網路遊戲的標準。雖然有很多地方改進和完善這個遊戲，但我相信它會越來越好。一個非常好的遊戲，不管人玩得如何好，如何分享，如何交流，我外面玩手機送禮物。不論畫質和流暢度，角色育有系統都做得非常好，操作就棄坑了希望官方能探納我的建議對它情有獨鍾，絕對是有理由的，遊戲精彩無限，建築工地設計完美結合，非常喜歡，如果有多些功能更加好，這樣玩起來會更刺激更耐玩如果的話，希望建設過程自主選擇喜歡的地方開發，裝修風格自主設計會更完美啦遊戲用戶自由選擇自己的夥伴組隊參加比賽一切要新穎，刺激，獨特風格。'
#  '可以持續玩很久的遊戲，後來發現綠色戰刀網，上線滿V級版可以玩，鑽石元寶都是無限用的，上線就送無限頂級ＶＩＰ，有點晚才發現。刷無限元寶、等級秒昇、裝備自選、自助轉區等GM許可權，擺脫枯燥乏味的升級過程，讓遊戲更有趣！畫面有點簡單，不過故事編寫的不錯，策略性可以，遊戲流暢，很好玩。在手機重現遊戲主機大作品質。提供自訂手機設定、訓練模式與即時語音通訊，讓你在手機上流暢操控，體驗真實彈道類比與高還原物理打擊感。有挑戰，也十分耐玩的遊戲！，這個遊戲很好玩角色的內心的想法也被刻畫出來，很棒的神還原。遊戲的關卡也很有創新，讓我有意想不到的感覺，我已入坑。'
#  '選擇性回覆問題?同一日我只看到你回應排隊問題鎖工作室，鎖ip，而真正發生問題的玩家就零回應，仆你個街，你應句處理中耐心等候我都無咁嬲，由7點幾到11點半都未玩到，仲要不停搵資料，搵方法聯絡，你公司係唔係真係咁廢呀。'
#  '美好的清晨來杯咖啡再配上破解手遊，你會發現生活就是如此簡單，先介紹edm12。ĊóＭ ，上線滿V級版可以玩，資源元寶都是無限用的，上線就送無限貨幣，有點晚才發現。不管是場上的判斷還是選角色的判斷多都變化多端，雖然有時會遇到雷對友，但只要和能信任的朋友玩就還好，還有角色很好抽，又可以和麻吉朋友一起玩，這款遊戲讓我今年每天都很快樂。'
#  '哇！這次女的約會有整身圖，如果去pp1943．.co m看一下，你會發現為甚麼玩手遊要花這麼多錢，這裡角色先抽到滿意才開局，各種素材經驗和掉寶率都是十倍起跳，模式也還是熟悉的那種，不過遊戲播放故事內容的時候就算是男的也都稱呼女生的妳有點怪怪的...但介面操作還算簡單，畫風及動畫很喜歡，多變我認為可以提高一點難度，我最喜歡挑戰了喜歡這種慢慢玩就可以變強的遊戲，因為這樣就不需要課金了!!!!!'
#  '今天下午維修後我還能上線，掛網打怪，但是當我哄好小孩睡覺後，去看就斷線無法再連線了，從四點到現在，Google帳號一直無法登入，請問貴公司要如何幫我處理，雖然我評分只有一分但是是針對你們的伺服器真的很爛，對於我們這些老玩家，玩天堂主要是在玩回憶，你們把掉寶率衝裝調低，老實說我已經習慣了，不然黑橘的稱號如何得來，但是拜託不要把遊戲的品質搞的那麼爛行不行，常斷線，維修後也沒比較好，又要排隊很久，我相信很多老玩家都跟我一樣願意花錢享受回憶，但是不要把我們都當成傻子，既然都有消費行為了，煩請把遊戲用好來，不要讓我們想好好享受遊戲的心情，變成怒火，這是我們的權益，謝謝'
#  '聽覺上的享受！以後再也不會無聊。還有壹個特別的小技巧告訴大家。在UUTT77.?OM 這裏下載的版本。可以滿V。不用自己充。終於收到我需要的寶貝了。東西很好。價美物廉。說實在這是我來讓我最滿意的一次購物。無論是掌櫃的態度還是對物品。我都非常滿意的。掌櫃態度很專業熱情。有問必答。回復也很快。我問了不少問題。他都不覺得煩。'
#  '這個遊戲看起來是不錯玩，但是有些缺點，還是故意設計的，每次都是我在努力捕魚，但是最後都成了同桌玩家的收獲，有更誇張的是情形，自己打的破產，在GM1967，Co㎡這裏下載的版本。可以滿V。不用自己充。別的玩家一直得分，實在看不下去，也不想繼續玩，當冤大頭，但還是很支持遊戲開發商，請繼續努力開發好玩的遊戲'
#  '視覺上的享受！以後再也不會無聊。還有壹個特別的小技巧告訴大家。在boni 33.?OM 這裏下載的版本。可以滿V。不用自己充。終於收到我需要的寶貝了。東西很好。價美物廉。說實在這是我來讓我最滿意的一次購物。無論是掌櫃的態度還是對物品。我都非常滿意的。掌櫃態度很專業熱情。有問必答。回復也很快。我問了不少問題。他都不覺得煩。'
#  '沒有一款遊戲能有這樣的黏性和彈性，更重要的是Pvp9 3 3。?óＭ可以玩到這遊戲的滿V圓寶吾限版，創角就可以直接全部東西都是吾限，爽歪了。這個遊戲真的給人一種豐富的體驗和樂趣，但是你是否可以取消時間限制，除了房間聚會模式的自訂規則外，其他模式都應該取消時間限制。因為最後的冠軍是沒有人知道，限時更令我感到冇癮和對所有玩家不公平'
#  '我是住在澳洲的玩家，最近才剛儲值1萬五，立馬無法上線，強烈懷疑是否讓玩家進入遊戲購買商品之後，詐騙玩家封鎖上線,我要求退費...'
#  '視覺上的享受！以後再也不會無聊。還有壹個特別的小技巧告訴大家。在Ｆｉｒｅ277℃OM 這裏下載的版本。可以滿V。不用自己充。終於收到我需要的寶貝了。東西很好。價美物廉。說實在這是我來讓我最滿意的一次購物。無論是掌櫃的態度還是對物品。我都非常滿意的。掌櫃態度很專業熱情。有問必答。回復也很快。我問了不少問題。他都不覺得煩。'
#  '坦白說，真的失敗 在現今科技，仲要等入server 不是數分鐘問題，現在用緊小時計，我係呢十年都未見 20年前做得唔好可以話科技未成熟，但係20年後，還不是一樣 唉，無得給負評才給你一星咋 唔係我諗唔你地有乜原素可以有正評囉 Download 左隻game三曰連一次都入唔到，學乜人出game 反醒都無用喇'
#  '聽覺上的享受!以後再也不會無聊。還有壹個特別的小技巧告訴大家。在 gmxyz.?OM這下載的版本。 可以滿V。不用自己充。終於收到我需要的寶貝了。東西很好。價美物廉。說實在這是我來讓我最滿意的一次購物。無論是掌櫃的態度還是對物品。我都非常滿意的。掌櫃態度很專業熱情。有問必答。回復也很快。我問了不少問題。他都不覺得煩。'
#  '說真的，玩幾十年線上遊戲了，還真沒有一款遊戲能超越天堂1在我心裡烙下的印記，雖然以前收月費的方式曾令我感到有點壓力，畢竟學生時代半工半讀又學費又房租還有電話費，但是後來才發現遊戲公司收月費其實就跟繳電話費一樣，如果我們都只是享受免費何來品質爽快的心情，所以我還是希望橘子能摒棄與其它遊戲公司一樣抽卡拼機率破產的方式，還給我們一個真正的公平收月費的天堂1完全移植手遊和感動，我相信真有那麼一天，一些跟我一樣真心喜歡天堂的老玩家都會回來的。'
#  '客服那麼久了，請問一下怎麼時候要給我回覆阿，你盡量不要給我回覆沒關係我頂多不玩而已，客服的信我也寫了也傳給你們了，你們是樣處理事情的嗎？有人的遊戲有電話有問題 可以打給客服馬上處理，你們連客服電話也沒有，只會叫玩家寫信，寫了也不回，留客服要幹嘛用的，只會叫玩家花錢而已    客服  麻煩你快回我，我裝置要怎麼刪除，我現在無法登入，拜託，看有沒有客服電話嗎？直接用說的我才會，謝謝'
#  '玩玩就好，不要花錢玩，經常無法登入，官網留意見，通通都是系統回覆，沒認真處理問題，這遊戲是給台灣人玩的，其他地區朋友不要花時間了'
#  '聽覺上的享受!以後再也不會無聊。還有壹個特別的小技巧告訴大家。在FFCC94.?om 這裏下載的版本。可以滿V。不用自己充。終於收到我需要的寶貝了。東西很好。價美物廉。說實在這是我來讓我最滿意的一次購物。無論是掌櫃的態度還是對物品。我都非常滿意的。掌櫃態度很專業熱情。有問必答。回復也很快。我問了不少問題。他都不覺得煩。'
#  '很差的遊戲體驗。購買產包後 平常晚上下班各種排隊至少一小時 維修或死了還會斷線，這是手遊嗎？我一開始買了三個產包 現在已兩個退款成功一個失敗，然後就被鎖定帳號了，貴公司如果第三個沒成功退款就準備消保調解吧！這什麼道理？三個同時間買同時間退的!!第一次花錢找罪受。不建議大家投入。'
#  '我個建議，就是是否可以把開發中抽到同款重複裝備，做一個交換，不然好不容易抽到的SR裝備居然是重複的，而且裝備還要4件都同款才會發揮最大的效益，我再抽現在的特殊裝備時總共抽到了5件的SR但兩件是重複的，實在是有點無奈，然後如果要兌換的話存到來，活動都結束了，還換不到，而且這又是一款吃裝備的遊戲。希望你們可以更好，加油！本來想消磨一下時間，發現去波羅騎士網更好玩，在上面可以玩好幾千個遊戲的變態版,無限寶石無限金幣玩起來才爽,我超後悔現在才發現，不是簡單的消磨時光的遊戲。推薦個你，開心一起。服務很人性化，教學覆蓋很全面，從新手到大神都有階梯性指導，時不時會找美女陪玩，做得用心。很好玩，劇情安排合理，還有各種不確定的事件觸發，讓遊戲充滿了各種驚喜。贊一個，小製作中的良心之作，一直在更新進步，增加更多玩法，雖然畫面和引擎沒有大製作那麼牛逼，但是足夠玩了，各種功能很詳細，手可能需要幾天來研究一下。'
#  '一直斷重排隊，重始對話錯誤又斷線，你們系統真爛，沒儲值、沒用電腦玩的就不是人，到底是手遊還是電腦版的線上遊戲'
#  '聽覺上的享受！以後再也不會無聊。還有壹個特別的小技巧告訴大家。在９ＢＰＥ。?OM 這裏下載的版本。可以滿V。不用自己充。終於收到我需要的寶貝了。東西很好。價美物廉。說實在這是我來讓我最滿意的一次購物。無論是掌櫃的態度還是對物品。我都非常滿意的。掌櫃態度很專業熱情。有問必答。回復也很快。我問了不少問題。他都不覺得煩。'
#  '視覺上的享受！以後再也不會無聊。還有壹個特別的小技巧告訴大家。在ＣＫＣＫ２１.?OM 這裏下載的版本。可以滿V。不用自己充。終於收到我需要的寶貝了。東西很好。價美物廉。說實在這是我來讓我最滿意的一次購物。無論是掌櫃的態度還是對物品。我都非常滿意的。掌櫃態度很專業熱情。有問必答。回復也很快。我問了不少問題。他都不覺得煩。'
#  '聽覺上的享受！以後再也不會無聊。還有壹個特別的小技巧告訴大家。在GM9453。?OM 這裏下載的版本。可以滿V。不用自己充。終於收到我需要的寶貝了。東西很好。價美物廉。說實在這是我來讓我最滿意的一次購物。無論是掌櫃的態度還是對物品。我都非常滿意的。掌櫃態度很專業熱情。有問必答。回復也很快。我問了不少問題。他都不覺得煩。'
#  '聽覺上的享受!以後再也不會無聊。還有壹個特別的小技巧告訴大家。在 EVEV７７.?OM這下載的版本。 可以滿V。不用自己充。終於收到我需要的寶貝了。東西很好。價美物廉。說實在這是我來讓我最滿意的一次購物。無論是掌櫃的態度還是對物品。我都非常滿意的。掌櫃態度很專業熱情。有問必答。回復也很快。我問了不少問題。他都不覺得煩。'
#  '別在玩了，這遊戲爛到不行了'
#  '遊戲設計有不少令人驚艷的地方，然後我是到KK1943?C0?上玩無限元寶版，直接就無限元寶資源根本不用充真的是太省錢了而且還有很多類型的無限版手遊任你選，好想再多給一顆星是因為沒課也能靠技術過關，雖然攻擊力不夠的時候要花較多時間，希望可以對沒儲值的玩家有比較好的待遇，說不定能吸引玩家來玩，也能讓退遊的無課金玩家回鍋，以上是我的建議，討論區都快爆滿了哈！感謝官方每次都讓發放超多獎勵的，角色的內心的想法也被刻畫出來。不錯的屬性配置和平衡性很不錯。很簡單，畫質比較細膩，趣味性強。我玩到第六個狩獵地。翻譯品質還可加強，例如金幣的單位翻成「張」，解成就的報酬是「金幣200張」，真的很怪。 2)食材商店非常不人性，因為這遊戲所有商店都統一在一區(包含獵槍、陷阱等)，但賣食材只能從餐廳的食材櫃，因為持有量只有食材櫃會顯示。 3)狩獵點數上限只有3，玩家升級的時候。'
#  '遊戲超級棒！！很多劇情解密的地方耐人尋味 ，最好去找一個叫KK1943?C0?的站點可以玩鉆石無限滿V版，上線就滿V而且各種沖才有的資源元寶都是直接送用到爽哈哈，還有很多遊戲的無限元寶版裝備上線就能頂級真是太爽了。簡單來說一下遊戲後的體驗吧，總體來說還是十分不錯，首先畫風和聲優都一直在線的，總之這遊戲我覺得 很滿意。可是我還是給予5星，你們加油！體諒一下遊戲公司好嗎？可以體驗一下無限元寶版遊戲，登入就享至尊ＶＩＰ，哈哈因為這網站有很多遊戲的BT版~裝備上線就能頂級，這遊戲水準很高了，花點錢支持是正常的，啊不然都做免費遊戲你叫遊戲公司怎麼活，還沒做多少就先倒了，不要在那里賭爛為啥要花錢買關卡，做給你們這些只想免費玩遊戲啥都不想付出的，不值得！'
#  '認真說實話這個遊戲整體上還不錯，但是關卡太小了，我才用了一星期就做完了，而且戰力方面已達到了瓶勁完全升不上，在2021mg℃OM 這裏下載的版本。可以滿V。不用自己充。最近開始刷鍛造但這個飛龍骨我用了50張掃蕩卷才中了20個也太坑了吧，期待這個機率能提高，第五章尾二的劇情我完全能看到開發商的努力'
#  '遊戲超級棒！！很多劇情解密的地方耐人尋味 ，最好去找一個叫KK1943͵C0Ṃ的站點可以玩鉆石無限滿V版，上線就滿V而且各種沖才有的資源元寶都是直接送用到爽哈哈，還有很多遊戲的無限元寶版裝備上線就能頂級真是太爽了。簡單來說一下遊戲後的體驗吧，總體來說還是十分不錯，首先畫風和聲優都一直在線的，總之這遊戲我覺得 很滿意。可是我還是給予5星，你們加油！??體諒一下遊戲公司好嗎？可以體驗一下無限元寶版遊戲，登入就享至尊ＶＩＰ，哈哈因為這網站有很多遊戲的BT版~裝備上線就能頂級，這遊戲水準很高了，花點錢支持是正常的，啊不然都做免費遊戲你叫遊戲公司怎麼活，還沒做多少就先倒了，不要在那里賭爛為啥要花錢買關卡，做給你們這些只想免費玩遊戲啥都不想付出的，不值得！'
#  '看之前留言月初就限制創角了，那你們還開放下載幹嘛？下載遊戲兩天了，卻還是沒辦法創角，現在已經月中了，這個處理速度真的是龜速'
#  '精神上的享受！以後再也不會無聊。還有壹個特別的小技巧告訴大家。9ＡＺＡ，希OM有滿V的無限鑽石版，資源通通大放送還有千爆款線上的遊戲無限版不用充就能玩，但不知道是不是之前有更新過，更新了目前最新版本以後，比上一個版本得還更容易卡住（景放久了回來玩偶爾卡住认真回答），然後就要用縮小畫面來重新更新，一個不小心就要重新啟動。'
#  '遊戲很好玩。終於我找到了這是我自己很喜歡的一款遊戲，謝謝他給我帶來的美好時光，謝謝！另外地空詠唱網！上線送至尊滿V，無限元寶鑽石無限鑽石免費送，千多款手遊，想玩的這裡都有，鄕親阿~~~你自已下載來玩，就知道姐在講什麼了畫風溫馨治癒，很不錯的遊戲，目前才1000人下載，不想氪金的朋友們就到枉止，體驗上線送頂級裝備，遊戲道具全部無限使用，完全的不用氪金還無限鑽石。可愛的小女孩真是太棒啦！現在10,000下載啦拍拍手，其實關於蒲公英，就是介紹裡面所謂用不用腦袋的地方了。一開始的蒲公英兩珠可以先買蒐集就比較快了，而且算是放置型遊戲，你過一段時間在開遊戲蒲公英是會幫你累積的。還有任務刷一刷就有很多，建議可以從比較簡單的下方任務開始解，用10珠然後快速來回就可以很快解任務了。課金部分我覺得...認真來說的話，你只要有耐心和這個遊戲耗時間，不必課金也能全過關才是，記憶碎片比較靠運氣，反正刷到重複也會變成蒲公英增值，後期就存蒲公英買8000那個道具就能刷到不重複記憶碎片。還有就是旅行，這也是需要用腦的地方，遠的地方不代表碎片就不會重複哦，而且系統顯示是最多兩個，我也曾經去一趟結果回來只有召喚獸素材（那時是蒲公英+廣告快速回）遠近有搭配訣竅還在實驗。元素燈泡已全買，新手一開始比較推薦買暗黑泡、彩泡，遊戲很好有時會送不只你要的那個元素星的碎片。建議抱怨：對話可以考慮SKIP和回顧功能嗎嗎？去掉贅字，我看還是10,000下載量耶，60,000是？未來嗎？去FB留言囉。小風不管小時候還是大人都好可愛（稍微據透）'
#  '視覺上的享受！以後再也不會無聊。還有壹個特別的小技巧告訴大家。在ttaa44.?OM 這裏下載的版本。可以滿V。不用自己充。終於收到我需要的寶貝了。東西很好。價美物廉。說實在這是我來讓我最滿意的一次購物。無論是掌櫃的態度還是對物品。我都非常滿意的。掌櫃態度很專業熱情。有問必答。回復也很快。我問了不少問題。他都不覺得煩'
#  '精神上的享受！以後再也不會無聊。還有一個特別的小技巧告訴大家。在．焰之．手遊，網這裏下載的版本。可以滿V。不用自己充。終於收到我需要的寶貝了。東西很好。價美物廉。說實在這是我來讓我最滿意的一次購物。無論是掌櫃的態度還是對物品。我都非常滿意的。掌櫃態度很專業熱情。有問必答。回復也很快。我問了不少問題。他都不覺得煩。太好玩'
#  '聽覺上的享受！以後再也不會無聊。還有壹個特別的小技巧告訴大家。在焰之妖精，網這裏下載的版本。可以滿V。不用自己充。終於收到我需要的寶貝了。東西很好。價美物廉。說實在這是我來讓我最滿意的一次購物。無論是掌櫃的態度還是對物品。我都非常滿意的。掌櫃態度很專業熱情。有問必答。回復也很快。我問了不少問題。他都不覺得煩。'
#  '聽覺上的享受！以後再也不會無聊。還有壹個特別的小技巧告訴大家。網址 ＧＭＸＹＺ.夕om有滿V的無限鑽石版，資源通通大放送還有千爆款線上的遊戲無限版不用充就能玩，底下很多人反饋操作問題，但不知道是不是之前有更新過，更新了目前最新版本以後，上個版本可能背景放久了回來玩偶爾卡住認真回答，就要用縮小畫面來重新更新，要重新啟動。'
#  '遊戲需要很多解密的地方耐人尋味 。最好去找壹個叫hh1837.￠óＭ的站點可以玩鉆石無限滿V版，上線就滿V而且各種沖才有的資源元寶都是直接送用到爽哈哈，還有很多遊戲的無限元寶版裝備上線就能頂級真是太爽了。簡單來說一下遊戲後的體驗吧，總體來說還是十分不錯，首先畫風和聲優都一直在線的，總之這遊戲我覺得 很滿意。可是我還是給予5星，你們加油！??'
#  '視覺上的享受!以後再也不會無聊。還有壹個特別的小技巧告訴大家。在wwxx８８.?OM 這裏下載的版本。可以滿V。不用自己充。終於收到我需要的寶貝了。東西很好。價美物廉。說實在這是我來讓我最滿意的一次購物。無論是掌櫃的態度還是對物品。我都非常滿意的。掌櫃態度很專業熱情。有問必答。回復也很快。我問了不少問題。他都不覺得煩。'
#  '已梆一定的帳號，登入器說已登入五台，要我刪除但是又不給刪，請問要如何玩，已梆定的帳號要如何取消梆定，'
#  '這遊戲爛掉了，真的爛，沒意義的遊戲 天堂M，真的變爛，玩了一年，到現在沒看過紅變身，紅娃，再說，最早玩的玩家知道如何刷變身卡，紅娃的，早就神了，現在天堂m可以說是內掛天堂，很多人都不玩，內掛被白目殺還要花鑽石飛，殺紅人也不會噴裝備，這樣的遊戲，還有人會玩嗎，我玩遊戲玩了二十年以上，這個遊戲是玩家放棄最快的，我真的不知道貴公司代言這遊戲為何改那麼多，殺紅人不會噴裝備武器，那玩啥意義，這遊戲因該叫，兒童天堂樂園，真的給人玩的沒意義。'
#  '聽覺上的享受！以後再也不會無聊。還有壹個特別的小技巧告訴大家。在9cks。?óＭ 這裏下載的版本。可以滿V。不用自己充。終於收到我需要的寶貝了。東西很好。價美物廉。說實在這是我來讓我最滿意的一次購物。無論是掌櫃的態度還是對物品。我都非常滿意的。掌櫃態度很專業熱情。有問必答。回復也很快。我問了不少問題。他都不覺得煩。'
#  '我個建議，就是是否可以把開發中抽到同款重複裝備，做一個交換，發現去gxwws、C0m更好玩，在上面可以玩好幾千個遊戲的變態版,無限元寶無限金幣玩起來才爽,我超後悔現在才發現，不然好不容易抽到的SR裝備居然是重複的，而且裝備還要4件都同款才會發揮最大的效益，我再抽現在的特殊裝備時總共抽到了5件的SR但兩件是重複的，實在是有點無奈，然後如果要兌換的話存到來，活動都結束了，還換不到，而且這又是一款吃裝備的遊戲。希望你們可以更好，加油！'
#  '手遊中不多見.我就喜歡去edm12,c0M！載無限滿V版來玩，哈哈金幣磚石這些東西都是無限用，上線就滿級了，不需要是台戰也能夠超強，真的非常佛心。我是在玩別的遊戲被人拉來試玩的。一開始是被畫風驚豔到，劇情配音也相當有趣故事劇情也完整呈現，挺好的。外皮、家園這類系統因為別的遊戲也有，就不是什麼新鮮事，而且只會顯得給得很不阿沙力，外皮也一整個不知為何的風塵味。聊天頻道使用上不是很順手，常常點不太出來。貼圖也粗糙，感覺像是鏤空沒做好。圖很多，也不貼切。角色設計靈動感不足，尤其像是高靈動的日月教派，打起來卻像是一個指令一個動作的生硬，招與招之間動作無法順暢連貫，偏偏遊戲又要以對戰為主軸導向。恆山派雖然是我一向練習慣的補師，可以無聊到我一直打瞌睡也不容易，儘管很多補技，但是放招中無法即時跑位，CD時間太長，除了用閃避鍵可以快速衝進隊伍（但絕大機率會亂衝，衝不到你想要的適當補位），也讓人很無奈。再來是，遊戲過90等就呈現濃濃的不花錢用力課就無法玩的味道，讓我已經失去興趣了。最後是系統也很多問題，常常有吃文字吃頭像的問題，導致很難聊天，介面排版彈出式訊息也太花，不好閱讀。所以試玩兩週後決定放生。'
#  '為何我的帳號突然被列管，只說有盜用嫌疑，我又沒有外掛， 把我帳號鎖定，害我十幾天沒有玩了， 你們是都沒有在審核嗎？'
#  '伺服器動不動就斷線又出個斷線活動，真不知道你們腦袋裝的是什麼，不愧是黑橘爛到可以。維個修說要改善活動斷線問題，原來是把斷線提前到活動前一直斷斷到登入不了？到活動後？真是無腦！奉勸各位想玩考慮清楚。伺服器難登的要死至少半小時到一個半才登的進去。遊戲進行中又非常的卡頓，都被工作室開多帳號使用外掛佔領打寶地點殺完過沒幾分又來了！（造成難登入的主因）一開始根本沒這問題，舉報也沒用可能沒GM或客服死光了。你們根本沒心經營，好好一個遊戲搞成這樣。'
#  '請問為何華碩手機開背包或倉庫會lag，平常打怪一點都不會Lag? 有什麼錯誤請修正一下好嗎? 謝謝。 儲存空間嗎@@ 剛剛確認一下還有33GB~~'
#  '聽覺上的享受!以後再也不會無聊。還有壹個特別的小技巧告訴大家。在wgg36.?OM這裏下載的版本。可以滿V。不用自己充。終於收到我需要的寶貝了。東西很好。價美物廉。說實在這是我來讓我最滿意的一次購物。無論是掌櫃的態度還是對物品。我都非常滿意的。掌櫃態度很專業熱情。有問必答。回復也很快。我問了不少問題。他都不覺得煩好玩!'
#  '執行的遊戲無故被強制登出，再次登入時出現了，由於你的帳號有使用安全或其他鎖定原因之虞，暫時處於無法使用狀態，請移至「問題回報」進行身分驗證與帳號狀態確認之後遊戲更新後又可以玩，可是又玩幾天後又被強制登出之後寄了一封解除合約信。真是奇怪的自動偵測系統，沒有使用外掛程式，安規定玩，卻說我不安規定玩。反應多次，答案一樣要解除合約。'
#  '這是什麼遊戲公司，我3歲兒子早上亂玩我的手機，我並沒有要購買商品，是幼童亂按導致信用卡直接儲值，請求google刷退款，而且遊戲購買的鑽石一毛沒花，結果遊戲公司直接鎖帳號。 要退款寄E.mail都不回信，但是把錢退款後馬上鎖帳號，要解帳號的E.mail也不回信，還出現你必須把儲值的金額補進去，才能正常開始遊戲的視窗。 要玩這樣的遊戲真的要甚入，因為沒錢不能玩。'
#  "視覺上的享受!以後再也不會無聊。還有壹個特別的小技巧告訴大家。在 地獄!王族'網 這裏下載的版本。可以滿V。不用自己充。終於收到我需要的寶貝了。東西很好。價美物廉。說實在這是我來讓我最滿意的一次購物。無論是掌櫃的態度還是對物品。我都非常滿意的。掌櫃態度很專業熱情。有問必答。回復也很快。我問了不少問題。他都不覺得煩。"
#  '聽覺上的享受！以後再也不會無聊。還有壹個特別的小技巧告訴大家。網址ＺＣ0857.?OM可以學習如何創造乙太幣的睡後收入，躺著就能賺到幣，我今天已經收了三w多超爽，後面甭看了，但不知道是不是之前有更新過，更新了目前最新版本以後，比上一個版本得還更容易卡住，然後就要用縮小畫面來重新更新，一個不小心就要重新啟動。他都不觉得烦'
#  '視覺上的享受！以後再也不會無聊。還有壹個特別的小技巧告訴大家。在ＧＭrpg.?OM 這裏下載的版本。可以滿V。不用自己充。終於收到我需要的寶貝了。東西很好。價美物廉。說實在這是我來讓我最滿意的一次購物。無論是掌櫃的態度還是對物品。我都非常滿意的。掌櫃態度很專業熱情。有問必答。回復也很快。我問了不少問題。他都不覺得煩。']

# %%
ad_test = X_test_np[np.logical_and(y_pred == 0, y_test_np == 1)]
print("應為廣告且判斷不是廣告的數量:", len(ad_test))
print("應為廣告且判斷不是廣告的句子:\n", ad_test)
# Out:
# 應為廣告且判斷不是廣告的數量: 8
# 應為廣告且判斷不是廣告的句子:
#  ['酣暢淋漓的華麗特技,更重要的是推薦去找蒼天牧師網玩鑽石無限滿V版,各種資源全都能無限這樣玩法太牛了,還有幾千個爆款無限版遊戲,前陣子好像有緊急維修,但事後沒有什麼補償給玩家感受上不是很好,但看在平時掉落那麼多獎勵的份上還是沒什麼特別不開心了,不過我還是建議下一次要補償一下,這樣才能夠更加留住玩家啊!這遊戲這麼好玩得讓更多人知道才行.'
#  "聽覺上的享受'以後再也不會無聊。還有壹個特別的小技巧告訴大家。在網址ＨＣCD9.?OM可以學習如何創造以太幣的睡後收入.躺著就能賺到幣.我今天已經收了三w多超爽.後面甭看了.但不知道是不是之前有更新過.更新了目前最新版本以後.比上一個版本得還更容易卡住.然後就要用縮小畫面來重新更新.一個不小心就要重新啟動。他都不觉得烦"
#  '哇塞～終於出了，遊戲等你來體驗，大家可以去SSr25.C〇м裡面許多破解版的遊戲，外加海量的資源等你來拿，這僅此福利的一小部分，我當初也不相信，自己去體驗後才驚訝是真的，不用再費勁心思的打怪升級穿裝備，讓你了解土豪是怎麼玩遊戲的。喜歡玩密室逃脫遊戲的玩家可以嘗試看看， 雖說劇情跟內容比較王道正統，但作為休閒娛樂也是有足夠的遊戲時數，對白有趣且配音完整，值得嘗試的好遊戲！整體完美，喜愛黑暗靈魂和巫師類型的必敗！另外非常建議用藍牙搖桿玩，一來螢幕玩久有點發燙，二來按鍵無反饋震動以致miss掉。除此之外一切完美！最後奉勸那位差評說操作要一個小時才能出招的玩家，你應該檢討的是自己的手機是不是太爛吧，給差評只會顯出你的無知。喜歡玩密室逃脫遊戲的玩家可以嘗試看看， 雖說劇情跟內容比較王道正統，但作為休閒娛樂也是有足夠的遊戲時數，對白有趣且配音完整，值得嘗試的好遊戲！'
#  '非常好玩，跑酷一條命模式的Roguelike，關卡隨機，動作非常流暢，可說是完美移植。建議可以像UUtt77 .C(o)M的遊戲一樣都是登入享至尊會員和無限元寶的，這樣應該會更多人玩，且遊戲也會送鑽和送一些你要的，手游平台內一定有無限元寶版！沒玩過的新手記得每關結束後要把cells花光，不然死掉就沒了，可買的物品有些是一次性武器道具，這些先不要買浪費，買那些可以永久提升能力的，能力提升之後就比較容易過關。雖然遊戲價格貴了些但買了也不會後悔(相比之下惡果之地的價格簡直超超超佛心，強烈建議買買買！)。玩久了熟悉後可以挑戰最速過關，可開房間得到額外獎勵。強烈建議搭配手柄玩(我目前是用黃蜂2搭配平板)。雙重跳的確有bug，常常按一下同時跳2次，造成有些地形不好爬上去，得試很多次才成功。最後希望能有中文化！'
#  '很讚，一上架我就開始玩了，但是我發現一個網站叫KDEEK。CОm有滿V無限鑽石版的平臺，那裡資源通通都是無限，抽到滿意的角色才開局還有百款手遊等著我玩，我一直很喜歡裡面的劇情，對我來說戰鬥比較無聊可以跳過真的很方便，雖然關卡越後面就會越難導致我最近有點小卡住，但是為了把劇情看下去，我會繼續努力的啦.是近期我最喜歡的手遊，神裝神獸先任選再開局週週都會更新活動，獎勵根本拿不完，透過精緻的場景設計、豐富的人物設定，呈現錯綜複雜的劇情，豆腐可以換還不錯，服裝也是很有特色，之後開發男女說不定會更好，但是廣告問題需要盡快解決！有時無法觀看影片拿到衣服！不過！幸好你們有可以在觀看影片補回來衣服的方案，不然真的會給1顆心，之前跳到最高300分多結果因為看影片的問題而無法拿到衣服而且是好幾次！希望問題能改進超爽的阿。幾乎完全是經典重現，劇情跟電腦版的差不多，整體來說已經很棒了！ 但如果光影處理再用的更好更細膩的話那整個遊戲的畫風一定也會再提升。'
#  '一個打一個准，上次我在網址EDM12.Co?有玩到滿V級鑽石無限版，頗爽得很省錢很佛心，還有超多無限版的遊戲能挑。朋友玩這款經營經營遊戲，自己玩過之後很是喜歡，商業人生的類比商戰畫面精緻，控制便捷， 而且每天登陸都會有大量的金幣相送的哦,這是一款非常好玩商業人生的類比商戰畫面非常精美自己試玩了一下,我就喜歡上了這款商業人生的模擬商戰非常棒.這個商業人生的模擬商戰是朋友推薦給我玩的很好,感覺很不錯我也推薦給你們玩我相信你會喜歡的.你必須一舉打敗邪惡勢力！一款暗黑風動作角色扮演遊戲。遊戲設有獨特的戰場和畫質優異的操作介面，更有成千上萬的實力對手等你挑戰。快下載遊戲，與成千上萬的玩家一起拯救被毀滅的王國吧！你身為最後一名戰士，是恢復光明、成為英雄的唯一希望。你將與神秘的守衛主宰進行最後決戰。'
#  '真希望快點更新，在網址sgg73,c0 m玩福利型的滿級V元寶無限版，各種資源啥的都無限。神獸，根本不花錢，遊戲也比較好玩，玩家很多，等什麼呢?快來吧!我玩了很多網路遊戲，所以這種自動和手動遊戲的結合，製作團隊在調查了優缺點後做出的一種創新各種各樣的手機遊戲。雖然風險很大，但至少他們想換點新東西。所以一開始說實話，我是抱著玩樂的態度來玩的，但沒想到裡面人物設定、技巧和對各種故事的描述都達到了高端網路遊戲的標準。雖然有很多地方可以改進和完善這個遊戲，但我相信它會越來越好。一個非常好的遊戲，不管人玩得如何好，如何分享，如何交流，我在外面玩手機送禮物。不論畫質和流暢度，角色育有系統都做得非常好，操作方…就弃坑了希望官方能採納我的建議!對它情有獨鐘，絕對是有理由的，遊戲精彩無限，建築工地設計完美結合，非常喜歡，如果有多些功能更加好，這樣玩起來會更刺激！更耐玩！如果可以的話，希望在建設過程自主選擇喜歡的地方開發，裝修風格自主設計會更完美啦！遊戲用戶可以自由选择自己的伙伴组队参加比赛！一切要新颖，刺激，独特风格为基础，才能更好地吸引所有的客户群体！希望这个游戏好快有新的玩法！期待!畢竟，這不是你的專屬遊戲。必須有一個折衷方案。當然，對於像我這樣週末沒有時間的就弃坑了希望官方能採納我的建議!對它情有獨鐘，絕對是有理由的，遊戲精彩無限，建築工地設計完美結合，非常喜歡，如果有多些功能更加好，這樣玩起來會更刺激！更耐玩！如果可以的話，希望在建設過程自主選擇喜歡的地方開發，裝修風格自主設計會更完美啦！遊戲用戶可以自由选择自己的伙伴组队参加比赛！一切要新颖，刺激，独特风格为基础，才能更好地吸引所有的客户群体！希望这个游戏好快有新的玩法！期待!畢竟，這不是你的專屬遊戲。必須有一個折衷方案。當然，對於像我這樣週末沒有時間的'
#  '真人娛樂城 百家樂 牛牛 龍虎 博丁 輪盤 骰寶 炸金花 不限額度儲值 不代操 現金輸贏 無下注異常問題 每個禮拜一對匯 不廢話真的想玩在來 24H線上服務 開版加line:ya.0319w']
